# %% [markdown]
# # Ricalcolo Completo: Thread-Aware Preprocessing & Embeddings
#
# Questo notebook esegue la pipeline di preprocessing ed embedding in un **ambiente isolato** (senza sovrascrivere i file originali).
#
# Tutti i risultati saranno salvati in nuovi file denominati `*_thread_aware.*` per distinguerli chiaramente dai precedenti.
#
# ## Obiettivo
# 1. Fixare il bug del filtro `has_thread` (causato dalla rimozione dei newline in `normalize_text`).
# 2. Applicare la nuova separazione semantica tra `content_new` e `THREAD:` per la generazione degli embeddings.
# 3. Ricalcolare interamente i vettori a 384 dimensioni tramite `BAAI/bge-small-en-v1.5` sui nuovi testi.

# %% [markdown]
# ## 1. Ricalcolo Preprocessing (Fix `has_thread`)
# Generiamo il nuovo dataset in `data/processed/jmail_emails_processed_thread_aware.parquet`.

# %%
from pathlib import Path
import json
import sys

PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT.parent != PROJECT_ROOT:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.utils.data_processing import run_processing_with_limit

print("Avvio ricalcolo Preprocessing su tutto il dataset...")
processing_metadata = run_processing_with_limit(env_file=PROJECT_ROOT / ".env", limit = 50000)

print("\n=== Preprocessing Completato ===")
print(f"Nuovo file generato: jmail_emails_processed_thread_aware.parquet")
print(f"Righe finali generate: {processing_metadata.get('output_row_count', 'N/A')}")
# Out:
# Avvio ricalcolo Preprocessing su tutto il dataset...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 from src.utils.data_processing import run_processing_with_limit, run_processing
#       2
#       3 print("Avvio ricalcolo Preprocessing su tutto il dataset...")
# ----> 4 processing_metadata = run_processing(env_file=".env")
#       5
#       6 print("\n=== Preprocessing Completato ===")
#       7 print(f"Nuovo file generato: jmail_emails_processed_thread_aware.parquet")
#
# File ~/Workspace/Projects/pizza-cluster/src/utils/data_processing.py:546, in run_processing(env_file)
#     536 def run_processing(env_file: str | Path = DEFAULT_ENV_FILE) -> dict[str, Any]:
#     537     """Process configured raw JMAIL data and write processed output plus metadata.
#     538
#     539     Example:
#    (...)    543         ```
#     544     """
# --> 546     return run_processing_with_limit(env_file=env_file, limit=None)
#
# File ~/Workspace/Projects/pizza-cluster/src/utils/data_processing.py:580, in run_processing_with_limit(env_file, limit)
#     573     processed_path = processed_path.with_name(
#     574         values.get("PROCESSED_EMAILS_SAMPLE_FILENAME", DEFAULT_TEST_PROCESSED_FILENAME)
#     575     )
#     576     metadata_path = metadata_path.with_name(
#     577         values.get("PROCESSING_SAMPLE_METADATA_FILENAME", DEFAULT_TEST_METADATA_FILENAME)
#     578     )
# --> 580 raw = pd.read_parquet(raw_path)
#     581 if is_sample:
#     582     raw = raw.head(limit).copy()
#
# File ~/Workspace/Projects/pizza-cluster/.venv/lib/python3.13/site-packages/pandas/io/parquet.py:671, in read_parquet(path, engine, columns, storage_options, dtype_backend, filesystem, filters, to_pandas_kwargs, **kwargs)
#     668 impl = get_engine(engine)
#     669 check_dtype_backend(dtype_backend)
# --> 671 return impl.read(
#     672     path,
#     673     columns=columns,
#     674     filters=filters,
#     675     storage_options=storage_options,
#     676     dtype_backend=dtype_backend,
#     677     filesystem=filesystem,
#     678     to_pandas_kwargs=to_pandas_kwargs,
#     679     **kwargs,
#     680 )
#
# File ~/Workspace/Projects/pizza-cluster/.venv/lib/python3.13/site-packages/pandas/io/parquet.py:253, in PyArrowImpl.read(self, path, columns, filters, dtype_backend, storage_options, filesystem, to_pandas_kwargs, **kwargs)
#     240 def read(
#     241     self,
#     242     path,
#    (...)    249     **kwargs,
#     250 ) -> DataFrame:
#     251     kwargs["use_pandas_metadata"] = True
# --> 253     path_or_handle, handles, filesystem = _get_path_or_handle(
#     254         path,
#     255         filesystem,
#     256         storage_options=storage_options,
#     257         mode="rb",
#     258     )
#     259     try:
#     260         pa_table = self.api.parquet.read_table(
#     261             path_or_handle,
#     262             columns=columns,
#    (...)    265             **kwargs,
#     266         )
#
# File ~/Workspace/Projects/pizza-cluster/.venv/lib/python3.13/site-packages/pandas/io/parquet.py:141, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     131 handles = None
#     132 if (
#     133     not fs
#     134     and not is_dir
#    (...)    139     # fsspec resources can also point to directories
#     140     # this branch is used for example when reading from non-fsspec URLs
# --> 141     handles = get_handle(
#     142         path_or_handle, mode, is_text=False, storage_options=storage_options
#     143     )
#     144     fs = None
#     145     path_or_handle = handles.handle
#
# File ~/Workspace/Projects/pizza-cluster/.venv/lib/python3.13/site-packages/pandas/io/common.py:935, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#    (...)    931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
# --> 935         handle = open(handle, ioargs.mode)
#     936     handles.append(handle)
#     938 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/suga/Workspace/Projects/pizza-cluster/src/notebooks/experiment/data/raw/jmail_emails.parquet'

# %% [markdown]
# ## 2. Generazione Nuovi Embeddings
# **ATTENZIONE:** Il tempo stimato per l'esecuzione su 1.75 milioni di record è di **circa 14 ore**.
# I nuovi risultati finiranno in `email_embeddings_thread_aware.npy`.

# %%
from src.utils.embedding_pipeline import run_embedding_pipeline

print("Avvio calcolo Embeddings (BAAI/bge-small-en-v1.5) token-aware...")
print("Attenzione: l'operazione durerà molte ore. Non chiudere o disconnettere il notebook.")

embedding_metadata = run_embedding_pipeline(env_file=PROJECT_ROOT / ".env")

print("\n=== Calcolo Embeddings Completato ===")
print("I nuovi vettori sono stati salvati in data/embeddings/email_embeddings_thread_aware.npy")
# Out:
# Avvio calcolo Embeddings (BAAI/bge-small-en-v1.5) token-aware...
# Attenzione: l'operazione durerà molte ore. Non chiudere o disconnettere il notebook.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Token-Aware Chunking:   0%|          | 0/42333 [00:00<?, ?it/s][transformers] Token indices sequence length is longer than the specified maximum sequence length for this model (1748 > 512). Running this sequence through the model will result in indexing errors
# Token-Aware Chunking: 100%|██████████| 42333/42333 [00:16<00:00, 2597.91it/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# Batches:   0%|          | 0/313 [00:00<?, ?it/s]
# Batches:   0%|          | 0/313 [00:00<?, ?it/s]
# Batches:   0%|          | 0/313 [00:00<?, ?it/s]
# Batches:   0%|          | 0/313 [00:00<?, ?it/s]
# Batches:   0%|          | 0/313 [00:00<?, ?it/s]
# Batches:   0%|          | 0/234 [00:00<?, ?it/s]
# === Calcolo Embeddings Completato ===
# I nuovi vettori sono stati salvati in data/embeddings/email_embeddings_thread_aware.npy
